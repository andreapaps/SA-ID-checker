# %%
id = 8605065397083
i=0

#Collecting all the pieces
sid = str(id)
DOB= sid[0:6]
Gen = sid[6]
SSS = sid[7:10]
C = sid[10]
A = sid[11]
Z = sid[12]
add_odd = 0
add_even =0
count = 0
even_str = '' 
even = 0
add = 0 

if int(Gen) < 5:
    Gen = 'Female'  #Donno how to do if else haha

if Gen != 'Female':
    Gen = 'Male'

if (int(C) ==0):
    C = 'SA Citizen'

if C != 'SA Citizen':
    C = 'Not SA Citizen'
        



for i in sid[0:12]:
    if (count % 2 != 0):
        even_str = even_str + i
    elif (count % 2 == 0):
        add_odd = add_odd + int(i)
        
    count = count +1

even = int(even_str)*2

for i in str(even):
    add_even = add_even + int(i)


add = add_odd + add_even        
control = 10 - int(str(add)[1])

if (control == int(Z)):
    print('ID is valid')
    print('Gender:'+ Gen)
    print('DOB(YYMMDD):'+DOB[0:2]+'/'+ DOB[2:4]+'/'+DOB[4:6])
    print(C)

if (control != int(Z)):
    print('ID is invalid')
# Out:
# ID is valid
# Gender:Male
# DOB(YYMMDD):86/05/06
# SA Citizen

# %%
def id_validator(id):
    i=0

    #Collecting all the pieces
    sid = str(id)
    DOB= sid[0:6]
    Gen = sid[6]
    SSS = sid[7:10]
    C = sid[10]
    A = sid[11]
    Z = sid[12]
    add_odd = 0
    add_even =0
    count = 0
    even_str = '' 
    even = 0
    add = 0 

    if int(Gen) < 5:
        Gen = 'Female'  #Donno how to do if else haha
    else:
        Gen = 'Male'

    if (int(C) ==0):
        C = 'SA Citizen'

    if C != 'SA Citizen':
        C = 'Not SA Citizen'


    for i in sid[0:12]:
        if (count % 2 != 0):
            even_str = even_str + i
        elif (count % 2 == 0):
            add_odd = add_odd + int(i)

        count = count +1

    even = int(even_str)*2

    for i in str(even):
        add_even = add_even + int(i)


    add = add_odd + add_even        
    control = 10 - int(str(add)[1])

    if (control == int(Z)):
        print('ID is valid')
        print('Gender:'+ Gen)
        print('DOB(YYMMDD):'+DOB[0:2]+'/'+ DOB[2:4]+'/'+DOB[4:6])
        print(C)

    if (control != int(Z)):
        print('ID is invalid')

id_validator(9302015064083)
id_validator(9302015064084)
id_validator(8908035403084)
# Out:
# ID is valid
# Gender:Male
# DOB(YYMMDD):93/02/01
# SA Citizen
# ID is invalid
# ID is valid
# Gender:Male
# DOB(YYMMDD):89/08/03
# SA Citizen
